# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data=r"D:\ML,DL,OPENCV ENVN\tile_yolo\tile.yaml",
    epochs=100,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.2  Python-3.9.25 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
